# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\hp\Downloads\height_weight_data.csv')
df.head()
# Out:
#    Height_cm  Weight_kg
# 0        165         60
# 1        170         70
# 2        158         55
# 3        180         80
# 4        175         68

# %%
plt.scatter(df['Weight_kg'],df['Height_cm'])
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
df.corr()
# Out:
#            Height_cm  Weight_kg
# Height_cm   1.000000   0.354811
# Weight_kg   0.354811   1.000000

# %%
import seaborn as sns 
sns.pairplot(df)

# %%
X=df[['Weight_kg']]
X
np.array(X).shape
# Out:
# (16, 1)

# %%
Y=df[['Height_cm']]
np.array(Y).shape
# Out:
# (16, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,random_state=7,test_size=0.20)

# %%
### standardization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
##Simple linear regression
from sklearn.linear_model import LinearRegression
regression=LinearRegression(n_jobs=-1)

regression.fit(X_train,y_train )
# Out:
# LinearRegression(n_jobs=-1)

# %%
from sklearn.linear_model import LinearRegression


regression = LinearRegression()
regression.fit(X_train, y_train)

regression.coef_
# Out:
# array([[5.32909806]])

# %%
print('coefficient or slope:', regression.coef_)
print('Intercept:', regression.intercept_)
# Out:
# coefficient or slope: [[5.32909806]]
# Intercept: [167.75]

# %%
##plot the training data 
plt.scatter(X_train,y_train)
plt.plot(X_train,regression.predict(X_train))

# %%
y_pred=regression.predict(X_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

y_pred = regression.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("MSE:", mse)
print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MSE: 18.387428008719066
# MAE: 3.3878079507278898
# RMSE: 4.288056437212442

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.22374974105671486
